# %%
import glob
import sys, os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline


from libs import gif

# %%
# !ls
# Out:
# build-gif.ipynb      スライド1.png        スライド4.png
# em_anim2.gif         スライド2.png        スライド5.png
# libs                 スライド3.png

# %%
imgs = []
for file_path in glob.glob('./スライド*.png'):
    #print(file_path)
    imgs.append(plt.imread(file_path))

# %%
gif.build_gif(imgs, saveto='em_anim2.gif', interval=3)

# %%
# !ls
# Out:
# EMアルゴリズム             スライド1.png
# build-gif-inception.ipynb  スライド2.png
# create_anim.ipynb          スライド3.png
# em_anim.gif                スライド4.png
# libs                       スライド5.png
