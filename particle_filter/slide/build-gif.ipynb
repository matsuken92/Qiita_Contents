# %%
import glob
import sys, os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
import IPython.display as ipyd

from libs import gif, nb_utils
from libs import utils

# Bit of formatting because I don't like the default inline code style:
from IPython.core.display import HTML
HTML("""<style> .rendered_html code { 
    padding: 2px 4px;
    color: #c7254e;
    background-color: #f9f2f4;
    border-radius: 4px;
} </style>""")
# Out:
# <style> .rendered_html code {
#     padding: 2px 4px;
#     color: #c7254e;
#     background-color: #f9f2f4;
#     border-radius: 4px;
# } </style>

# %%
imgs = []
for file_path in glob.glob("./process_v002/*.png"):
    #print(file_path)
    imgs.append(plt.imread(file_path))

# %%
interval_sec = 2
gif.build_gif(imgs, saveto='particle_filter_{}.gif'.format(interval_sec), interval=interval_sec)
